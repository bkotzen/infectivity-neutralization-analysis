# %% [markdown]
# # Correlations

# %%
import pickle
import torch
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Read in data

# %%
# Infectivity
mutation_file = 'results/mutation_infectivity_effects.csv'
infectivity = pd.read_csv(mutation_file)

# %%
# Neutralization
neutralization_file = 'results/mutation_neutralization_effects.csv'
neutralization = pd.read_csv(neutralization_file)

# %%
# PyR0
pyro_file = 'data/PyR0/2023-09-19/mutations.tsv'
pyro = pd.read_csv(pyro_file, sep='\t', usecols=['mutation', 'R / R_A', 'R / R_A 95% ci lower', 'R / R_A 95% ci upper']).rename(columns={'mutation':'Mutation'})
pyro = pyro[pyro['Mutation'].str.startswith('S:')]
pyro['Mutation'] = pyro['Mutation'].apply(lambda x: x[2:])

# %%
# BVAS
bvas_file = 'data/BVAS/2023-09-20/allele_summary.csv'
bvas = pd.read_csv(bvas_file).rename(columns={'Unnamed: 0':'Mutation'}).drop(columns='Rank')
bvas = bvas[bvas['Mutation'].str.startswith('S:')]
bvas['Mutation'] = bvas['Mutation'].apply(lambda x: x[2:])

# %%
# Join
df = pd.DataFrame()
df = pd.merge(infectivity, neutralization, on='Mutation', suffixes=[' Infectivity', ' Neutralization'])
df = pd.merge(df, pyro, on='Mutation', suffixes=['', ''])
df = pd.merge(df, bvas, on='Mutation', suffixes=['', ''])
df
# Out:
#   Mutation  Mean Infectivity  Std Infectivity  Mean Neutralization  \
# 0    V213G          0.340941         0.455107             0.643294
# 1    Q493R          0.145612         0.237969            -0.516441
# 2    R346T         -0.012822         0.211066            -0.999970
# 3    R346K         -0.019653         0.456901             0.092831
# 4     T19R         -0.127052         0.432457            -0.055020
# 5     T76I         -0.390298         0.331571            -0.537121
# 6    T478K         -0.532237         0.536735             0.927153
# 7    L452R         -0.583046         0.277506            -0.578415
# 8    G339D         -0.610106         0.326907            -1.197481
#
#    Std Neutralization   R / R_A  R / R_A 95% ci lower  R / R_A 95% ci upper  \
# 0            0.177605  1.057070              1.057030               1.05711
# 1            0.152512  0.962116              0.961992               0.96224
# 2            0.191064  1.167680              1.167250               1.16812
# 3            0.093485  1.098130              1.098090               1.09818
# 4            0.078049  1.007000              1.006960               1.00704
# 5            0.226741  1.031250              1.031040               1.03146
# 6            0.289431  1.388530              1.385010               1.39205
# 7            0.135396  1.176720              1.176530               1.17691
# 8            0.231329  1.054520              1.054440               1.05460
#
#         PIP      Beta   BetaStd  ConditionalBeta  ConditionalBetaStd
# 0  0.012438 -0.000046  0.009131        -0.006068            0.105169
# 1  1.000000 -0.532805  0.071332        -0.532805            0.071332
# 2  1.000000  0.379058  0.024746         0.379058            0.024746
# 3  1.000000  0.335846  0.023385         0.335846            0.023385
# 4  0.900275  0.275853  0.134424         0.309105            0.099849
# 5  1.000000 -0.168680  0.025677        -0.168680            0.025677
# 6  0.007356 -0.000125  0.013750        -0.001110            0.040941
# 7  1.000000  0.510087  0.041544         0.510087            0.041544
# 8  0.017432  0.000910  0.010515         0.054853            0.060890

# %%
assert False, 'NEUTRALIZATOIN RESULTS ARE WRONG'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 assert False, 'NEUTRALIZATOIN RESULTS ARE WRONG'
#
# AssertionError: NEUTRALIZATOIN RESULTS ARE WRONG

# %% [markdown]
# ## Compare

# %%
df[['Mean Infectivity', 'Mean Neutralization', 'R / R_A', 'Beta', 'PIP']].corr()
# Out:
#                      Mean Infectivity  Mean Neutralization   R / R_A  \
# Mean Infectivity             1.000000             0.257441 -0.453326
# Mean Neutralization          0.257441             1.000000  0.421468
# R / R_A                     -0.453326             0.421468  1.000000
# Beta                        -0.221912            -0.052222  0.363702
# PIP                          0.145740            -0.407243 -0.353771
#
#                          Beta       PIP
# Mean Infectivity    -0.221912  0.145740
# Mean Neutralization -0.052222 -0.407243
# R / R_A              0.363702 -0.353771
# Beta                 1.000000  0.194167
# PIP                  0.194167  1.000000

# %%
# Infectivity vs PyR0
fig, ax = plt.subplots(figsize=(5,5))
sns.regplot(x='Mean Infectivity',
            y='R / R_A',
            data=pd.merge(infectivity, pyro, on='Mutation').rename(columns={'Mean':'Mean Infectivity'}),
            ax=ax);

# %%
# Infectivity vs BVAS Beta
fig, ax = plt.subplots(figsize=(5,5))
sns.regplot(x='Mean Infectivity',
            y='Beta',
            data=pd.merge(infectivity, bvas, on='Mutation').rename(columns={'Mean':'Mean Infectivity'}),
            ax=ax);

# %%
# Neutralization vs PyR0
fig, ax = plt.subplots(figsize=(6,6))
sns.regplot(x='Mean Neutralization',
            y='R / R_A',
            data=df[['Mutation', 'Mean Neutralization', 'R / R_A']],
            ax=ax)

# %%
# Neutralization vs Infectivity

# %%
# Neutralization vs BVAS Beta
